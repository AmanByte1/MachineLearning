# %%
from byteflow import Agent
from byteflow.providers.ollama_provider import OllamaProvider

agent = Agent(provider=OllamaProvider())
print(agent.chat("hello"))
# Out:
# Hello again! It's great to chat with you again. How have you been doing since our last conversation? Did you make any progress on that project you were working on or do you have some new questions or challenges you'd like to tackle together? I'm all ears and ready to help in any way I can!

# %%
from byteflow import Agent
from byteflow.providers.ollama_provider import OllamaProvider

agent = Agent(provider=OllamaProvider())
print(agent.run("add 10 and 20"))
# Out:
# I remember our previous conversation! You asked me to add 10 and 20. The answer is... (drumroll please)... 30!
#
# So, to recap: 10 + 20 = 30. Does that help with whatever you're working on? Or would you like to explore something else?

# %%
from byteflow import Agent
from byteflow.providers.ollama_provider import OllamaProvider

agent = Agent(provider=OllamaProvider())
print(agent.code("add 10 and 20"))
# Out:
# {'code': 'result = 10 + 20\nprint(result)', 'explanation': "Here's a simple solution that adds 10 and 20:\n\nThis is a straightforward math operation that can be done in Python using the built-in `+` operator.\n\n```python\nresult = 10 + 20\nprint(result)\n```", 'executed': False, 'result': None}

# %%
result = 10 + 20
print(result)
# Out:
# 30

# %%
from byteflow import Agent
from byteflow.providers.ollama_provider import OllamaProvider

agent = Agent(provider=OllamaProvider())
print(agent.chat("add 10 and 20"))
# Out:
# We had a simple math question earlier!
#
# So, to recall, we're adding 10 and 20. To do that, I'll just calculate the sum:
#
# 10 + 20 = 30
#
# So, the answer is 30!

# %%
from byteflow import Agent
from byteflow.providers.ollama_provider import OllamaProvider

agent = Agent(provider=OllamaProvider())

print(agent.run("hii"))
print(agent.post("launching my open source project ByteFlow"))
# Out:
# Hello! It's great to start our conversation. What brings you here today?
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 7
#       3
#       4 agent = Agent(provider=OllamaProvider())
#       5
#       6 print(agent.run("hii"))
# ----> 7 print(agent.post("launching my open source project ByteFlow"))
#
# AttributeError: 'Agent' object has no attribute 'post'
