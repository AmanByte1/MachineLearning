# %%
from byteflow import Agent
from byteflow.providers.ollama_provider import OllamaProvider

agent = Agent(provider=OllamaProvider())
print(agent.chat("hello"))
# Out:
# Hello again, Aman! It's great to chat with you. I see you've already asked me to add 10 and 20 earlier, and I provided a simple Python code snippet to do so. If you need a refresher or want to explore more ways to calculate the sum, just let me know!
#
# By the way, I noticed that you tried to draft a social post earlier, but it seemed like there was an error. Don't worry if you're still figuring things out - we can work through it together. What's on your mind regarding this task or any other topic you'd like to discuss?

# %%
from byteflow import Agent
from byteflow.providers.ollama_provider import OllamaProvider

agent = Agent(provider=OllamaProvider())
print(agent.run("add 10 and 20"))
# Out:
# ["[Tool Error - draft_social_post]: Agent.draft_social_post_tool() missing 1 required positional argument: 'topic'"]

# %%
from byteflow import Agent
from byteflow.providers.ollama_provider import OllamaProvider

agent = Agent(provider=OllamaProvider())
print(agent.code("add 10 and 20"))
# Out:
# {'code': 'num1 = 10\nnum2 = 20\n\nresult = num1 + num2\n\nprint(result)', 'explanation': 'Here is the response:\n\nHey Aman! To add 10 and 20, we can use a simple code snippet in Python. Here it is:\n```python\nnum1 = 10\nnum2 = 20\n\nresult = num1 + num2\n\nprint(result)\n```\nWhen you run this code, it will print the sum of 10 and 20, which is... (drumroll please)... 30!', 'executed': False, 'result': None}

# %%
result = 10 + 20
print(result)
# Out:
# 30

# %%
from byteflow import Agent
from byteflow.providers.ollama_provider import OllamaProvider

agent = Agent(provider=OllamaProvider())
print(agent.chat("add 10 and 20"))
# Out:
# Hey Aman! I'm happy to help you with that.
#
# To add 10 and 20, we can use a simple code snippet in Python (assuming that's what you're looking for). Here it is:
#
# ```
# num1 = 10
# num2 = 20
#
# result = num1 + num2
#
# print(result)
# ```
#
# When you run this code, it will print the sum of 10 and 20, which is... (drumroll please)... 30!
#
# If you're using a different programming language or tool, feel free to let me know and I'll do my best to help with that too.
#
# Oh, by the way, remember how we got an error earlier when trying to add numbers? That was because we were trying to convert 'None' into a float. We don't want that kind of trouble again!

# %%
from byteflow import Agent
from byteflow.providers.ollama_provider import OllamaProvider

agent = Agent(provider=OllamaProvider())

print(agent.run("hii"))
print(agent.post("launching my open source project ByteFlow"))
# Out:
# Hi again, Aman! It's great to hear from you. I see you've got a friendly "hi" there. Don't worry if you don't have anything specific on your mind right now; we can just catch up and see where the conversation takes us.
#
# By the way, how did you feel about that Python code snippet I shared earlier? Was it helpful in understanding how to add 10 and 20? Or do you have any questions or need further clarification?
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 7
#       3
#       4 agent = Agent(provider=OllamaProvider())
#       5
#       6 print(agent.run("hii"))
# ----> 7 print(agent.post("launching my open source project ByteFlow"))
#
# AttributeError: 'Agent' object has no attribute 'post'
